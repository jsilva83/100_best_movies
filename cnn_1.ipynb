# %% [markdown]
# <a href="https://colab.research.google.com/github/jsilva83/100_best_movies/blob/master/cnn_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import h5py as h5

# %%
df1 = pd.read_csv("gene_network_description.csv", index_col= 0)

# %%
df1.tail()
# Out:
#       into/exonic      gene    chr       bps       bpe mutation1 mutation2  \
# 18965      exonic  MAPK8IP2  chr22  51043278  51043278         G         A
# 18966    intronic  MAPK8IP2  chr22  51044243  51044243         C         T
# 18967      exonic      ARSA  chr22  51065301  51065301         C         A
# 18968    intronic    SHANK3  chr22  51137094  51137094         G         A
# 18969      exonic    SHANK3  chr22  51153371  51153371         G         A
#
#        index_col  gene_id              chrbp
# 18965      18965     6140  chrchr22:51043278
# 18966      18966     6140  chrchr22:51044243
# 18967      18967     6141  chrchr22:51065301
# 18968      18968     6142  chrchr22:51137094
# 18969      18969     6142  chrchr22:51153371

# %%
df1.shape
# Out:
# (18970, 10)

# %%
df2 = pd.read_csv("connection_weights_example.csv", index_col=0)
df2.tail()
# Out:
#          chr  node_layer_0  node_layer_1  weights_0        layer0_name  \
# 18965  chr22         18965          6140  -0.003387  chrchr22:51043278
# 18966  chr22         18966          6140   0.004645  chrchr22:51044243
# 18967  chr22         18967          6141   0.000351  chrchr22:51065301
# 18968  chr22         18968          6142  -0.007807  chrchr22:51137094
# 18969  chr22         18969          6142   0.005980  chrchr22:51153371
#
#        weights_1 layer1_name  raw_importance
# 18965  -0.000004    MAPK8IP2    1.207460e-08
# 18966  -0.000004    MAPK8IP2   -1.655854e-08
# 18967  -0.000002        ARSA   -5.570541e-10
# 18968  -0.000005      SHANK3    3.536527e-08
# 18969  -0.000005      SHANK3   -2.708691e-08

# %%
df2.shape
# Out:
# (18970, 8)

# %%
df3 = pd.read_csv("subjects.csv", index_col=0)
df3.head()
# Out:
#     labels  genotype_row
# id
# 0        0             0
# 1        0             1
# 2        0             2
# 3        0             3
# 4        0             4

# %%
df3.shape
# Out:
# (11214, 2)

# %%
df3_0 = df3[df3['labels'] == 0]
df3_0
# Out:
#        labels  genotype_row
# id
# 0           0             0
# 1           0             1
# 2           0             2
# 3           0             3
# 4           0             4
# ...       ...           ...
# 11206       0         11206
# 11207       0         11207
# 11208       0         11208
# 11209       0         11209
# 11210       0         11210
#
# [6245 rows x 2 columns]

# %%
df3_1 = df3[df3['labels'] == 1]
df3_1
# Out:
#        labels  genotype_row
# id
# 95          1            95
# 96          1            96
# 97          1            97
# 98          1            98
# 99          1            99
# ...       ...           ...
# 11145       1         11145
# 11146       1         11146
# 11211       1         11211
# 11212       1         11212
# 11213       1         11213
#
# [4969 rows x 2 columns]

# %% [markdown]
# # Read H5 File.

# %%
data5 = h5.File("genotype.h5", "r")   # Reads into like a python dictionary

# %%
list(data5.keys()) # What are the dictionary keys?
# Out:
# ['data']

# %%
dset1 = data5['data']

# %%
dset1.shape
# Out:
# (11214, 18970)

# %%
arr0 = dset1[0]
len(arr0)
# Out:
# 18970

# %%
arr0
# Out:
# array([2, 0, 2, ..., 2, 2, 2], dtype=int32)

# %%
arr1 = dset1[1]
arr1
# Out:
# array([2, 1, 2, ..., 2, 1, 2], dtype=int32)

# %%
arr1000 = dset1[1000]
arr1000
# Out:
# array([2, 0, 2, ..., 2, 1, 2], dtype=int32)
